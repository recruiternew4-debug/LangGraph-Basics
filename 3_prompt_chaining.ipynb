# %%
from langgraph.graph import StateGraph,START,END
from langchain_google_genai import GoogleGenerativeAI
from dotenv import load_dotenv
from typing import TypedDict

# %%
load_dotenv()
model=GoogleGenerativeAI(model='gemini-2.5-flash')

# %%
#state
class BlogState(TypedDict):

    title:str
    outline:str
    content:str

# %%
def create_outline(state: BlogState)-> BlogState:
    #fetch title
     title=state['title']
    #call llm generation
     prompt=f'Generate an outline for a blog on the topic-{title} '
     outline=model.invoke(prompt)
    #update state
     state['outline']=outline

     return state

# %%
def create_blog(state:BlogState)-> BlogState:
#fetch title & outline
   title=state['title']
   outline=state['outline']

   prompt=f'write a detail blog on the title -{title} using the following outline \n{outline}'
   content=model.invoke(prompt)

#update the state of content
   state['content']=content

   return state

# %%
graph=StateGraph(BlogState)

#nodes
graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)


#edges
graph.add_edge(START,'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)

workflow=graph.compile()

# %%
initial_state={'title':'Rise of AI in india'}
final_state=workflow.invoke(initial_state)
print(final_state)
# Out:
# {'title': 'Rise of AI in india', 'outline': 'Here\'s a comprehensive outline for a blog post on "The Rise of AI in India," designed to be engaging, informative, and well-structured:\n\n---\n\n## Blog Title Options:\n\n*   **India\'s AI Ascent: Unpacking the Revolution Transforming the Nation**\n*   **The AI Tsunami: How India is Riding the Wave of Artificial Intelligence**\n*   **From Code to Culture: The Rapid Rise of AI in India**\n*   **Beyond the Hype: Understanding India\'s Growing AI Footprint**\n\n---\n\n## Blog Outline: India\'s AI Ascent\n\n### I. Introduction: Setting the Stage for an AI Revolution\n\n*   **A. The Global AI Buzz:** Briefly touch upon the worldwide excitement and transformative potential of AI.\n*   **B. India\'s Unique Position:** Highlight why India is particularly interesting in the AI landscape – large talent pool, digital adoption, diverse challenges.\n*   **C. Thesis Statement:** India is rapidly emerging as a significant player in the global AI arena, not just adopting but actively shaping AI solutions for its unique context and beyond, promising profound economic and social impact.\n*   **D. What Readers Will Learn:** Briefly outline the key areas the blog will cover (catalysts, sectors, challenges, future).\n\n### II. The Catalysts: Why Now for India?\n\n*   **A. Digital Infrastructure Boom:**\n    *   1. Widespread internet penetration (Jio effect, affordable data).\n    *   2. Growing smartphone adoption and digital literacy.\n*   **B. A Vast Talent Pool:**\n    *   1. Large number of STEM graduates.\n    *   2. Growing interest and skills in data science, machine learning, and AI.\n    *   3. English proficiency aiding global collaboration.\n*   **C. Government Initiatives & Vision:**\n    *   1. "AI for All" strategy (NITI Aayog, MeitY).\n    *   2. Focus on "Responsible AI" and ethical guidelines.\n    *   3. Investment in research and development (e.g., National AI Portal).\n*   **D. Thriving Startup Ecosystem:**\n    *   1. Increased VC funding and incubators for AI-focused startups.\n    *   2. Culture of innovation and problem-solving.\n*   **E. Data Abundance:**\n    *   1. Large population generating vast amounts of data.\n    *   2. Digitalization of government services and financial transactions.\n\n### III. AI Across Sectors: Impact and Innovation\n\n*   **A. Healthcare:**\n    *   1. Diagnostics (e.g., AI for early disease detection in radiology, ophthalmology).\n    *   2. Drug discovery and personalized medicine.\n    *   3. Remote patient monitoring and virtual assistance.\n    *   *Example:* AI solutions for accessible healthcare in rural areas.\n*   **B. Agriculture:**\n    *   1. Crop yield prediction and optimization.\n    *   2. Pest and disease detection.\n    *   3. Precision farming and weather forecasting.\n    *   *Example:* Government initiatives using AI for farmer advisories.\n*   **C. Finance & Banking:**\n    *   1. Fraud detection and cybersecurity.\n    *   2. Personalized banking and credit scoring (e.g., for underserved populations).\n    *   3. Algorithmic trading and risk assessment.\n*   **D. Education:**\n    *   1. Personalized learning platforms and adaptive content.\n    *   2. Automated grading and administrative tasks.\n    *   3. Skill development and vocational training.\n*   **E. Manufacturing & Retail:**\n    *   1. Supply chain optimization and predictive maintenance.\n    *   2. Customer experience enhancement (chatbots, recommendations).\n    *   3. Automation and quality control.\n*   **F. Public Services & Governance:**\n    *   1. Smart city initiatives.\n    *   2. Disaster management and resource allocation.\n    *   3. Citizen engagement and grievance redressal.\n\n### IV. Key Players and Ecosystem Drivers\n\n*   **A. Indian Startups & Innovators:**\n    *   1. Emerging unicorns and promising ventures (mention types of solutions).\n    *   2. Focus on solving local problems with global scalability.\n*   **B. Tech Giants (Global & Indi ...

# %%
final_state['content']
# Out:
# '## India\'s AI Ascent: Unpacking the Revolution Transforming the Nation\n\nFrom the bustling streets of Mumbai to the innovative tech hubs of Bengaluru, a silent yet profound revolution is underway. Artificial Intelligence (AI), once a futuristic concept, is rapidly integrating into the fabric of Indian society, promising to reshape industries, empower communities, and solve some of the nation\'s most pressing challenges. The global AI buzz is undeniable, with its transformative potential capturing the imagination of researchers, entrepreneurs, and governments worldwide. But India, with its vast talent pool, burgeoning digital adoption, and diverse socio-economic landscape, presents a particularly fascinating case study in this global narrative.\n\nIndia is rapidly emerging as a significant player in the global AI arena, not just adopting but actively shaping AI solutions for its unique context and beyond, promising profound economic and social impact. This blog will delve into the powerful catalysts driving this ascent, explore the pervasive impact of AI across key sectors, introduce the major players propelling this change, frankly discuss the challenges that lie ahead, and envision the exciting future India is building with AI at its core.\n\n### The Catalysts: Why Now for India?\n\nIndia\'s journey to becoming an AI powerhouse isn\'t accidental; it\'s the result of a confluence of strategic developments and inherent strengths:\n\n*   **A. Digital Infrastructure Boom:** The last decade has witnessed an unprecedented surge in digital connectivity. The "Jio effect," with its affordable data plans, has democratized internet access, bringing millions online. This, coupled with the widespread adoption of smartphones and growing digital literacy, has created a fertile ground for AI applications, generating vast amounts of digital data essential for training AI models.\n*   **B. A Vast Talent Pool:** India boasts one of the world\'s largest pools of STEM graduates, a critical asset for the AI industry. There\'s a growing interest and burgeoning skills in data science, machine learning, and AI among this demographic. Furthermore, English proficiency among a significant portion of the workforce aids seamless global collaboration and access to international research.\n*   **C. Government Initiatives & Vision:** The Indian government has demonstrated a clear vision for AI. Initiatives like NITI Aayog\'s "AI for All" strategy and the Ministry of Electronics and Information Technology (MeitY)\'s focus on digital transformation underscore a commitment to leveraging AI for national development. The emphasis on "Responsible AI" and ethical guidelines from the outset aims to ensure equitable and fair deployment. Investments in research and development, exemplified by the National AI Portal, further solidify this strategic push.\n*   **D. Thriving Startup Ecosystem:** India\'s startup ecosystem is vibrant and dynamic. AI-focused startups are attracting significant Venture Capital (VC) funding and benefiting from numerous incubators and accelerators. This culture of innovation and problem-solving is driving the creation of bespoke AI solutions tailored for the Indian market and beyond.\n*   **E. Data Abundance:** With a population of over 1.4 billion, India generates an immense volume of data daily. This "data goldmine," further enriched by the digitalization of government services (like Aadhaar and UPI) and financial transactions, provides unparalleled fuel for training robust and accurate AI models.\n\n### AI Across Sectors: Impact and Innovation\n\nAI is not just an abstract concept; it\'s tangible, delivering real-world impact across diverse sectors in India:\n\n*   **A. Healthcare:** AI is revolutionizing healthcare delivery, especially in a country with varied access to medical facilities.\n    *   **Diagnostics:** AI-powered tools are assisting in early disease detection, such as analyzing radiology scans for anomalies or identifying  ...

# %%
#To visualize the graph
from IPython.display import Image
Image(workflow.get_graph().draw_mermaid_png())
